# %% [markdown]
# # Twitter Data Collection
# The goal of this is to collect data from Twitter.
#
# If you run into an issue this can typically handle it.
# `jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10`

# %%
#This will import some required libraries.
import sys 
import ruamel.yaml 
#This is your configuration file. 
general_yaml='../../config/config.yaml'
with open(general_yaml, 'r') as yaml:
    cf=ruamel.yaml.round_trip_load(yaml, preserve_quotes=True)

twitter_yaml='../../config/twitter/config.yaml'
with open(twitter_yaml, 'r') as yaml_t:
    cf_t=ruamel.yaml.round_trip_load(yaml_t, preserve_quotes=True)


    #This will allow us to import some useful utilities. 
if cf['docker']:
    cf_t['path']=cf['docker_path']
else:
    cf_t['path']=cf['local_path']

sys.path.append(cf_t['path']+"/twitterutils") 
import importlib
import twitterutils as tu 
importlib.reload(tu)
#initialize some variables.
cf_t=tu.twitter_init(cf_t)
#print(ruamel.yaml.dump(cf_g, sys.stdout, Dumper=ruamel.yaml.RoundTripDumper))

# %%
import pandas as pd
df=pd.DataFrame.from_csv(cf_t['names_path'])
df=df.drop_duplicates(subset='screen_name', keep="first")
','.join(list(df['screen_name']))
df[0:49]
# Out:
#            screen_name
# index
# 1      jasonkuruzovich
# 2        analyticsdojo
# 4                    4
# 5                    5
# 6                    6
# 7                    7
# 8                    8
# 9                    9
# 10                  10
# 11                  11
# 12                  12
# 13                  13
# 14                  14
# 15                  15
# 16                  16
# 17                  17
# 18                  18
# 19                  19
# 20                  20
# 21                  21
# 22                  22
# 23                  23
# 24                  24
# 25                  25
# 26                  26
# 27                  27
# 28                  28
# 29                  29
# 30                  30
# 31                  31
# 32                  32
# 33                  33
# 34                  34
# 35                  35
# 36                  36
# 37                  37
# 38                  38
# 39                  39
# 40                  40
# 41                  41
# 42                  42
# 43                  43
# 44                  44
# 45                  45
# 46                  46
# 47                  47
# 48                  48
# 49                  49
# 50                  50

# %%
s=0
for i in range(math.ceil(len(df)/50)):
    #val=','.join(list(df[s:(s+49)]))
    val=df[s:(s+49)]
    print(val)
    s+=49
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a78e331dfc6f> in <module>()
#       1 s=0
# ----> 2 for i in range(math.ceil(len(df)/50)):
#       3     #val=','.join(list(df[s:(s+49)]))
#       4     val=df[s:(s+49)]
#       5     print(val)
#
# NameError: name 'math' is not defined

# %%
import math
for loop in (math.ceil(len(df)/50)):
    print(loop)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-56ce2f2990ab> in <module>()
#       1 import math
# ----> 2 for loop in (math.ceil(len(df)/50)):
#       3     print(loop)
#
# TypeError: 'int' object is not iterable

# %%
twitter= tu.create_twitter_auth(cf_t)

# %%
#This will collect user profiles. 
importlib.reload(tu)
profiles_fn=tu.get_profiles(twitter, df['screen_name'], cf_t)
# Out:
# Searching twitter for User profile:  jasonkuruzovich
# user 491
# user 0
# Searching twitter for User profile:  analyticsdojo
# user 491
# user 0

# %%
#This will collect user timelines.
importlib.reload(tu)
tu.profiles_to_timelines(twitter, profiles_fn, cf_t)
# Out:
# user: JasonKuruzovich Total tweets: 490 File tweets: 490
# Got them all
# user: dflanegan Total tweets: 9964 File tweets: 3198
# Go get some more
# Getting data for:  dflanegan
# Got 0 new tweets for dflanegan...
# Retreived tweets for  2  profiles.

# %%
print(cf_t['names_path'])
import csv
with open(cf_t['names_path'], 'r') as f:
    reader = csv.reader(f)
    names = pd.DataFrame(reader)
print(type(names))
print(names)
# Out:
# /Users/jasonkuruzovich/githubdesktop/admin-tools/config/twitter/screen_names.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-471deaec88d5> in <module>()
#       3 with open(cf_t['names_path'], 'r') as f:
#       4     reader = csv.reader(f)
# ----> 5     names = pd.DataFrame(reader)
#       6 print(type(names))
#       7 print(names)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     323                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#     324         elif isinstance(data, collections.Iterator):
# --> 325             raise TypeError("data argument can't be an iterator")
#     326         else:
#     327             try:
#
# TypeError: data argument can't be an iterator

# %%
#profile_last_update	profile_total_tweets	timeline_last_update	timeline_total_tweets	timeline_limit	timeline_limit_date
import pandas as pd
df=pd.DataFrame.from_csv(cf_t['names_path'])
df=names.drop_duplicates(subset='screen_name', keep="first")
for index, name in df.iterrows():
    print(row['screen_name'])
# Out:
# jasonkuruzovich
# analyticsdojo

# %%
names.DataFrame.to_csv(cf_t['names_path'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-128a4ed9d8f6> in <module>()
# ----> 1 names.DataFrame.to_csv(cf_t['names_path'])
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
import csv, codecs
import sys, re
import os.path
import json
from dateutil import parser
tweetfile = file("historical-tweets.csv", "w")
tweetwriter = csv.writer(tweetfile)

retweetfile = file("historical-retweets.csv", "w")
retweetwriter = csv.writer(retweetfile)
